# %%
import subprocess
def clean_report_list(report_list):
    for row in report_list:
        for j in range(len(row)):
            if row[j] == '<REST>':
                row[j] = 'REST'    
            elif isinstance(row[j], list):
                for k in range(len(row[j])):
                    if '#' in row[j][k]:
                        row[j][k] = row[j][k].replace('#', r'\#')
            elif isinstance(row[j], str) and '#' in row[j]:
                row[j] = row[j].replace('#', r'\#')
    return report_list
# Your list of data
test1 = [[1, 3, '<REST>', 'D5'], [1, 4, ['D4', 'G4', 'D5'], 'D5'], [1, 7, '<REST>', ['D5', 'B5']], [2, 1, '<REST>', 'G5'], [2, 2, ['D4', 'G4', 'D5'], 'G5'], [2, 3, '<REST>', ['D4', 'G4', 'D5']], [2, 4, ['D4', 'G4', 'D5'], 'A5'], [2, 5, '<REST>', ['D5', 'G5']], [2, 6, ['D4', 'G4', 'D5'], '<REST>'], [3, 2, ['G4', 'B4'], ['B4', 'D5', 'G5']], [4, 3, ['G4', 'B4'], ['E4', 'G4', 'B4']], [4, 5, ['G4', 'B4'], 'A4'], [4, 8, ['G4', 'B4'], ['D5', 'B5']], [5, 3, ['G4', 'B4'], 'D5'], [5, 4, ['G4', 'B4'], ['D4', 'G4', 'D5']], [5, 6, ['G4', 'B4'], ['D5', 'B5']], [6, 2, ['F#4', 'A4'], '<REST>'], [6, 3, ['F#4', 'A4'], 'G5'], [6, 4, ['E4', 'G4'], ['D5', 'E5', 'G5']], [6, 5, ['E4', 'G4'], 'B4'], [7, 1, '<REST>', 'G5'], [7, 3, ['G4', 'B4'], 'A5'], [8, 2, ['G4', 'B4'], 'D5'], [8, 3, ['G4', 'B4'], ['D5', 'B5']], [8, 6, ['G4', 'B4'], ['D5', 'E5', 'G5']], [8, 7, 'A4', 'G5'], [9, 5, ['G4', 'B4'], 'G5'], [10, 2, ['F#4', 'A4'], '<REST>'], [10, 4, ['E4', 'G4'], 'E5'], [11, 2, ['G4', 'B4', 'D5'], 'E5'], [12, 1, ['F#4', 'A4', 'D5'], ['G4', 'B4']], [12, 2, ['F#4', 'A4', 'D5'], ['G4', 'B4']], [12, 3, 'D5', ['G4', 'B4']], [12, 4, 'B4', ['E4', 'G4']], [13, 1, ['G4', 'B4', 'D5'], 'E5'], [13, 3, 'D5', ['G4', 'B4']], [14, 1, ['D5', 'E5', 'G5'], ['E4', 'G4']], [14, 3, ['D5', 'E5', 'G5'], ['D5', 'G5', 'B5']], [15, 1, '<REST>', ['F#4', 'A4']], [15, 2, ['B4', 'D5', 'G5'], 'D5'], [16, 2, 'D5', 'E5'], [16, 3, 'D5', ['D5', 'E5', 'G5']], [16, 4, 'E5', 'B4'], [17, 3, ['D5', 'B5'], ['F#4', 'A4']], [18, 1, '<REST>', 'E5'], [18, 2, 'G5', ['G4', 'B4']], [18, 3, 'B5', '<REST>'], [19, 3, 'D5', ['E4', 'G4']], [19, 4, 'E5', 'A5'], [20, 2, 'D5', ['F#4', 'A4', 'D5']], [20, 3, 'E5', ['G4', 'B4']], [20, 4, ['D5', 'G5', 'B5'], ['F#4', 'A4']], [21, 2, ['B4', 'D5', 'G5'], ['D5', 'G5', 'B5']], [21, 6, ['D5', 'C6'], '<REST>'], [21, 8, ['D5', 'G5'], 'G5'], [22, 4, 'A5', ['D5', 'E5', 'G5']], [22, 5, 'A5', ['D5', 'B5']], [22, 6, 'G5', 'A4'], [23, 1, '<REST>', ['D4', 'G4', 'D5']], [23, 5, 'G5', 'E5'], [24, 1, '<REST>', 'D5'], [24, 4, 'E5', 'A4'], [24, 6, ['D5', 'G5'], ['D4', 'G4', 'D5']], [25, 3, ['D5', 'B5'], ['G4', 'B4']], [26, 2, 'G5', ['G4', 'B4']], [27, 3, 'D5', ['D5', 'B5']], [28, 2, 'D5', ['D5', 'G5']], [28, 3, 'E5', '<REST>'], [28, 4, ['D5', 'G5', 'B5'], ['D5', 'E5', 'G5']], [29, 2, ['B4', 'D5', 'G5'], '<REST>'], [29, 6, ['D5', 'C6'], '<REST>'], [29, 7, ['D5', 'B5'], ['D5', 'E5', 'G5']], [29, 8, ['D5', 'G5'], 'D5'], [30, 2, 'G5', 'E5'], [30, 4, 'A5', 'G4'], [30, 5, 'A5', ['G4', 'B4']], [31, 3, '<REST>', ['D5', 'G5']], [31, 4, ['D4', 'G4', 'D5'], '<REST>'], [31, 5, '<REST>', 'G4'], [31, 6, ['D4', 'G4', 'D5'], 'D5'], [31, 7, '<REST>', 'G4'], [31, 8, ['D4', 'G4', 'D5'], ['D5', 'C6']], [32, 1, '<REST>', 'G5'], [32, 2, ['D4', 'G4', 'D5'], ['D5', 'E5', 'G5']], [32, 3, '<REST>', 'E5'], [32, 4, ['D4', 'G4', 'D5'], ['D5', 'B5']], [32, 5, '<REST>', ['D5', 'G5']], [32, 7, '<REST>', 'A4'], [33, 1, '<REST>', ['D5', 'F#5', 'A5']], [33, 3, ['G4', 'B4'], ['F#4', 'A4']], [33, 4, ['G4', 'B4'], '<REST>'], [33, 5, ['G4', 'B4'], ['B4', 'D5', 'G5']], [33, 6, ['G4', 'B4'], ['D4', 'G4', 'D5']], [33, 7, 'A4', 'D5'], [34, 1, '<REST>', ['E4', 'G4']], [34, 2, ['G4', 'B4'], 'B5'], [34, 3, ['G4', 'B4'], ['D5', 'G5']], [34, 7, 'A4', 'A5'], [34, 8, ['G4', 'B4'], 'D5'], [35, 1, '<REST>', 'B4'], [35, 3, ['G4', 'B4'], 'B5'], [35, 4, ['G4', 'B4'], 'G5'], [35, 6, ['G4', 'B4'], '<REST>'], [35, 7, 'A4', 'G5'], [35, 8, ['F#4', 'A4'], ['D5', 'G5', 'B5']], [36, 5, ['E4', 'G4'], ['G4', 'B4']], [36, 6, 'D5', '<REST>'], [36, 7, 'B4', 'A5'], [37, 1, '<REST>', 'G5'], [37, 2, ['G4', 'B4'], ['D5', 'E5', 'G5']], [37, 3, ['G4', 'B4'], 'D5'], [37, 6, ['G4', 'B4'], ['D5', 'B5']], [37, 7, 'A4', '<REST>'], [37, 8, ['G4', 'B4'], ['D5', 'B5']], [38, 2, ['G4', 'B4'], 'G5'], [38, 3, ['G4', 'B4'], 'G5'], [38, 4, ['G4', 'B4'], 'A5'], [38, 5, ['G4', 'B4'], ['E4', 'G4']], [38, 6, 'A4', 'D5'], [38, 7, ['G4', 'B4'], 'G5'], [39, 1, '<REST>', 'E5'], [39, 2, ['G4', 'B4'], ['D4', 'G4', 'D5']], [39, 3, ['G4', 'B4'], '<REST>'], [39, 4, ['G4', 'B4'], 'A5'], [39, 6, ['G4', 'B4'], 'D5'], [39, 7, 'A4', ['D4', 'G4', 'D5']], [39, 8, ['F#4', 'A4'], 'A5'], [40, 1, '<REST>', 'D5'], [40, 3, ['F#4', 'A4'], '<REST>'], [40, 4, ['E4', 'G4'], '<REST>'], [40, 5, ['E4', 'G4'], ['D5', 'G5']], [40, 6, 'D5', 'A5'], [40, 7, 'B4', '<REST>'], [41, 1, '<REST>', ['D5', 'B5']], [41, 2, ['G4', 'B4', 'D5'], '<REST>'], [41, 3, 'D5', 'A4'], [41, 4, 'B4', 'A5'], [41, 5, 'A4', ['D5', 'C6']], [41, 6, 'G4', 'A5'], [42, 1, ['F#4', 'A4', 'D5'], 'A4'], [42, 2, ['F#4', 'A4', 'D5'], ['D5', 'B5']], [42, 3, 'D5', '<REST>'], [42, 4, 'B4', '<REST>'], [42, 5, 'A4', '<REST>'], [42, 6, 'G4', 'B5'], [43, 1, ['G4', 'B4', 'D5'], 'B5'], [43, 2, ['G4', 'B4', 'D5'], ['D4', 'G4', 'D5']], [43, 3, 'D5', 'A5'], [43, 4, 'B4', '<REST>'], [43, 5, 'A4', 'A5'], [43, 6, 'G4', '<REST>'], [44, 1, ['D5', 'E5', 'G5'], ['G4', 'B4']], [44, 2, ['D5', 'E5', 'G5'], ['D4', 'G4', 'D5']], [44, 3, ['D5', 'E5', 'G5'], 'G5'], [44, 4, ['D5', 'E5', 'G5'], ['D5', 'C6']], [44, 5, ['D5', 'E5', 'G5'], '<REST>'], [44, 6, ['D5', 'E5', 'G5'], ['G4', 'B4']], [44, 7, ['D5', 'F#5', 'A5'], 'D5'], [44, 8, ['D5', 'F#5', 'B5'], ['D5', 'G5']], [45, 1, '<REST>', 'D5'], [45, 2, ['B4', 'D5', 'G5'], 'A5'], [45, 3, 'D5', ['D5', 'G5']], [45, 4, 'E5', 'A4'], [45, 5, 'G5', ['G4', 'B4']], [45, 6, 'D5', 'G4'], [46, 1, '<REST>', 'D5'], [46, 2, 'D5', ['D5', 'E5', 'G5']], [46, 4, 'E5', ['D5', 'E5', 'G5']], [46, 5, ['D5', 'B5'], ['G4', 'B4']], [46, 6, ['D5', 'G5'], ['D4', 'G4', 'D5']], [47, 1, '<REST>', ['D4', 'G4', 'D5']], [47, 2, 'G5', 'A5'], [47, 3, ['D5', 'B5'], ['E4', 'G4']], [47, 4, ['D5', 'C6'], 'A5'], [47, 5, ['D5', 'B5'], ['D5', 'G5']], [47, 6, ['D5', 'G5'], ['D4', 'G4', 'D5']], [48, 1, '<REST>', 'G5'], [48, 2, 'G5', ['D5', 'G5']], [48, 3, 'B5', '<REST>'], [48, 4, 'A5', ['G4', 'B4']], [48, 5, 'A5', 'D5'], [48, 6, 'G5', ['G4', 'B4']], [49, 1, '<REST>', ['G4', 'B4']], [49, 2, ['B4', 'D5', 'G5'], '<REST>'], [49, 3, 'D5', ['D5', 'F#5', 'B5']], [49, 4, 'E5', ['F#4', 'A4']], [49, 5, 'G5', ['F#4', 'A4']], [49, 6, 'E5', 'D5'], [50, 1, '<REST>', 'G5'], [50, 2, 'D5', ['G4', 'B4']], [50, 3, 'E5', ['F#4', 'A4']], [50, 4, ['D5', 'G5', 'B5'], 'A4'], [51, 1, ['D5', 'G5', 'B5'], ['G4', 'B4']], [51, 2, ['B4', 'D5', 'G5'], 'A5'], [51, 3, '<REST>', ['G4', 'B4']], [51, 4, 'G5', ['G4', 'B4']], [51, 5, ['D5', 'B5'], 'B5'], [51, 6, ['D5', 'C6'], 'D5'], [51, 7, ['D5', 'B5'], '<REST>'], [51, 8, ['D5', 'G5'], 'G5'], [52, 1, '<REST>', 'D5'], [52, 2, 'G5', ['G4', 'B4', 'D5']], [52, 3, 'B5', ['D4', 'G4', 'D5']], [52, 4, 'A5', ['D5', 'B5']], [52, 5, 'A5', ['G4', 'B4']], [52, 6, 'G5', ['G4', 'B4']], [53, 1, '<REST>', 'G5'], [53, 2, ['B4', 'D5', 'G5'], ['G4', 'B4']], [53, 4, 'E5', ['G4', 'B4']], [53, 5, 'G5', '<REST>'], [53, 6, 'D5', '<REST>'], [54, 1, '<REST>', 'A5'], [54, 2, 'D5', 'G5'], [54, 3, 'D5', ['D5', 'B5']], [54, 4, 'E5', 'G5'], [54, 5, ['D5', 'B5'], ['D5', 'G5']], [54, 6, ['D5', 'G5'], ['E4', 'G4']], [55, 1, '<REST>', 'D5'], [55, 2, 'G5', 'A5'], [55, 3, ['D5', 'B5'], 'D5'], [55, 4, ['D5', 'C6'], '<REST>'], [55, 5, ['D5', 'B5'], ['D5', 'G5']], [55, 6, ['D5', 'G5'], 'B5'], [56, 1, '<REST>', 'A5'], [56, 2, 'G5', 'A4'], [56, 3, 'B5', 'G5'], [56, 4, 'A5', ['D5', 'B5']], [56, 5, 'A5', 'A4'], [57, 2, ['B4', 'D5', 'G5'], 'E5'], [57, 4, 'E5', ['F#4', 'A4']], [57, 5, 'G5', 'A5'], [57, 7, 'E5', '<REST>'], [58, 1, '<REST>', ['G4', 'B4']], [58, 3, 'E5', ['G4', 'B4']], [58, 4, ['D5', 'G5', 'B5'], 'G5'], [59, 1, ['D5', 'G5', 'B5'], ['D5', 'E5', 'G5']], [59, 2, ['B4', 'D5', 'G5'], 'G5'], [59, 3, '<REST>', ['F#4', 'A4']], [59, 4, 'G5', 'D5'], [59, 5, ['D5', 'B5'], ['B4', 'D5', 'G5']], [59, 6, ['D5', 'C6'], 'A5'], [59, 7, ['D5', 'B5'], '<REST>'], [59, 8, ['D5', 'G5'], 'A4'], [60, 1, '<REST>', 'G5'], [60, 2, 'G5', ['D5', 'F#5', 'A5']], [60, 3, 'B5', 'A4'], [60, 4, 'A5', '<REST>'], [60, 5, 'A5', 'D5'], [60, 6, 'G5', ['G4', 'B4']], [61, 1, '<REST>', ['G4', 'B4']], [61, 2, 'D5', '<REST>'], [61, 3, 'B5', ['B4', 'D5', 'G5']], [61, 4, 'A5', ['D5', 'B5']], [61, 5, 'A5', ['D4', 'G4', 'D5']], [61, 6, 'G5', 'A5'], [61, 7, 'G5', '<REST>'], [61, 8, 'E5', ['F#4', 'A4']], [62, 1, 'D5', ['D5', 'G5', 'B5']], [62, 2, 'D5', ['B4', 'D5', 'G5']], [62, 3, 'D5', 'G5'], [62, 4, 'D5', 'A4'], [62, 5, 'A5', ['G4', 'B4']], [62, 6, 'G5', 'A5'], [63, 1, '<REST>', ['G4', 'B4']], [63, 2, 'D5', ['D5', 'G5']], [63, 3, 'D5', 'A5'], [63, 4, 'D5', ['B4', 'D5', 'G5']], [63, 5, 'A5', 'G5'], [64, 1, '<REST>', 'B5'], [64, 2, 'D5', ['D5', 'C6']], [64, 3, 'D5', 'B5'], [64, 4, 'D5', 'E5'], [64, 5, 'A5', 'B5'], [64, 6, 'A5', '<REST>'], [65, 1, 'G5', 'A5'], [65, 2, 'D5', ['D5', 'B5']], [65, 3, 'B5', ['G4', 'B4']], [65, 4, 'A5', ['G4', 'B4']], [65, 5, 'A5', '<REST>'], [65, 6, 'G5', 'D5'], [65, 7, 'G5', 'A5'], [65, 8, 'E5', 'B4'], [66, 1, 'D5', ['G4', 'B4']], [66, 2, 'D5', ['D5', 'G5']], [66, 3, 'D5', '<REST>'], [67, 1, '<REST>', 'B4'], [67, 2, 'D5', 'E5'], [67, 3, 'D5', '<REST>'], [67, 4, 'D5', '<REST>'], [67, 5, 'A5', 'E5'], [67, 6, 'G5', 'A4'], [68, 1, '<REST>', 'G5'], [68, 2, 'D5', '<REST>'], [68, 4, 'D5', 'B5'], [68, 5, 'A5', 'G5'], [68, 6, 'A5', 'B5'], [69, 1, 'G5', '<REST>'], [69, 2, '<REST>', 'B5'], [70, 1, '<REST>', 'D5'], [71, 1, '<REST>', ['D5', 'C6']], [72, 1, '<REST>', 'D5'], [73, 2, 'G5', 'D5'], [73, 3, 'D5', 'G5'], [73, 4, 'E5', ['D5', 'C6']], [73, 5, 'G5', 'A5'], [73, 6, 'E5', 'D5'], [74, 1, '<REST>', 'G5'], [74, 3, 'E5', '<REST>'], [74, 4, 'B5', 'G5'], [75, 1, 'B5', 'D5'], [75, 2, 'G5', ['F#4', 'A4']], [75, 3, '<REST>', 'G4'], [75, 4, 'G5', 'B5'], [75, 5, 'B5', 'D5'], [75, 6, 'C6', ['G4', 'B4', 'D5']], [75, 7, 'B5', '<REST>'], [75, 8, 'G5', ['B4', 'D5', 'G5']], [76, 1, '<REST>', 'G5'], [76, 2, 'G5', 'D5'], [76, 3, 'B5', '<REST>'], [76, 4, 'A5', 'G5'], [76, 5, 'A5', 'D5'], [76, 6, 'G5', 'G4'], [77, 1, '<REST>', 'A5'], [77, 2, ['B4', 'D5', 'G5'], 'A5'], [77, 3, 'D5', 'A4'], [77, 4, 'E5', 'G5'], [77, 5, 'G5', 'D5'], [77, 6, 'D5', ['D5', 'C6']], [78, 1, '<REST>', 'G5'], [78, 3, 'D5', ['D4', 'G4', 'D5']], [78, 4, 'E5', '<REST>'], [78, 5, ['D5', 'B5'], '<REST>'], [78, 6, ['D5', 'G5'], 'B4'], [79, 2, 'G5', 'A5'], [79, 3, ['D5', 'B5'], 'G5'], [79, 4, ['D5', 'C6'], 'D5'], [79, 5, ['D5', 'B5'], 'D5'], [80, 1, '<REST>', 'B5'], [80, 2, 'G5', 'B5'], [80, 3, 'B5', 'A5'], [80, 5, 'A5', 'D5'], [80, 6, 'G5', ['D5', 'C6']], [81, 1, '<REST>', 'A5'], [81, 2, ['B4', 'D5', 'G5'], 'D5'], [81, 3, 'D5', 'E5'], [81, 4, 'E5', ['D5', 'C6']], [81, 5, 'G5', 'D5'], [81, 7, 'E5', '<REST>'], [82, 1, '<REST>', 'G5'], [82, 2, 'D5', 'G5'], [82, 3, 'E5', 'G6'], [82, 4, ['D5', 'G5', 'B5'], 'B4'], [83, 1, ['D5', 'G5', 'B5'], 'E5'], [83, 2, ['B4', 'D5', 'G5'], 'G5'], [83, 3, '<REST>', ['D5', 'C6']], [83, 5, ['D5', 'B5'], '<REST>'], [83, 6, ['D5', 'C6'], 'A5'], [83, 7, ['D5', 'B5'], 'D5'], [84, 1, '<REST>', 'B5'], [84, 2, 'G5', '<REST>'], [84, 4, 'A5', 'D5'], [84, 5, 'A5', '<REST>'], [84, 6, 'G5', 'D5'], [85, 1, '<REST>', 'D5'], [85, 4, 'A5', ['D5', 'B5']], [85, 5, 'A5', '<REST>'], [85, 6, 'G5', '<REST>'], [85, 8, 'E5', 'G4'], [86, 1, 'D5', ['D5', 'B5']], [86, 2, 'D5', ['D4', 'G4', 'D5']], [86, 3, 'D5', '<REST>'], [86, 4, 'D5', 'G4'], [86, 5, 'A5', 'G5'], [86, 6, 'G5', 'A5'], [87, 1, '<REST>', ['G4', 'B4', 'D5']], [87, 2, 'D5', 'G5'], [87, 3, 'D5', 'G5'], [87, 4, 'D5', ['G4', 'B4']], [87, 5, 'A5', ['G4', 'B4']], [87, 6, 'G5', 'E5'], [88, 1, '<REST>', ['G4', 'B4']], [88, 2, 'D5', '<REST>'], [88, 3, 'D5', 'A4'], [88, 4, 'D5', 'G5'], [88, 5, 'A5', '<REST>'], [88, 6, 'A5', ['G4', 'B4', 'D5']], [89, 3, 'B5', 'G5'], [89, 4, 'A5', 'G5'], [89, 5, 'A5', '<REST>'], [89, 6, 'G5', 'A5'], [89, 7, 'G5', ['D5', 'B5']], [89, 8, 'E5', ['G4', 'B4']], [90, 1, 'D5', ['G4', 'B4']], [90, 4, 'D5', ['D5', 'C6']], [90, 5, 'A5', ['G4', 'B4']], [90, 6, 'G5', 'A5'], [91, 1, '<REST>', 'G5'], [91, 2, 'D5', '<REST>'], [91, 3, 'D5', 'E5'], [91, 4, 'D5', ['D4', 'G4', 'D5']], [91, 5, 'A5', ['B4', 'D5', 'G5']], [92, 1, '<REST>', 'D5'], [92, 2, 'G5', ['D5', 'C6']], [92, 3, 'B5', ['D5', 'G5']], [92, 4, 'A5', 'D5'], [92, 5, 'A5', 'E5'], [92, 6, 'G5', '<REST>'], [93, 2, '<REST>', 'D5'], [93, 3, 'D4', ['D5', 'C6']], [93, 4, 'G4', '<REST>'], [93, 5, 'A4', ['D5', 'B5']], [94, 1, 'B4', 'G5'], [94, 2, 'D5', 'G4'], [94, 3, 'G5', 'B5'], [94, 4, 'A5', '<REST>'], [94, 5, 'B5', ['G4', 'B4', 'D5']], [94, 6, 'D6', ['E4', 'G4']], [94, 7, 'G6', ['D4', 'G4', 'D5']], [95, 1, 'G6', ['B4', 'D5', 'G5']]]
test2 = [[1, 2, '<REST>', 'D5'], [1, 3, ['D4', 'G4', 'D5'], 'D5'], [2, 2, '<REST>', ['D5', 'B5']], [3, 0, '<REST>', 'G5'], [3, 1, ['D4', 'G4', 'D5'], 'G5'], [3, 2, '<REST>', ['D4', 'G4', 'D5']], [4, 0, ['D4', 'G4', 'D5'], 'A5'], [4, 1, '<REST>', ['D5', 'G5']], [4, 2, ['D4', 'G4', 'D5'], '<REST>'], [5, 2, ['G4', 'B4'], ['B4', 'D5', 'G5']], [8, 2, ['G4', 'B4'], ['E4', 'G4', 'B4']], [9, 1, ['G4', 'B4'], 'A4'], [10, 1, ['G4', 'B4'], ['D5', 'B5']], [11, 1, ['G4', 'B4'], 'D5'], [11, 2, ['G4', 'B4'], ['D4', 'G4', 'D5']], [12, 1, ['G4', 'B4'], ['D5', 'B5']], [13, 2, ['F#4', 'A4'], '<REST>'], [14, 0, ['F#4', 'A4'], 'G5'], [14, 1, ['E4', 'G4'], ['D5', 'E5', 'G5']], [14, 2, ['E4', 'G4'], 'B4'], [14, 5, '<REST>', 'G5'], [15, 0, ['G4', 'B4'], 'A5'], [16, 3, ['G4', 'B4'], 'D5'], [16, 4, ['G4', 'B4'], ['D5', 'B5']], [17, 2, ['G4', 'B4'], ['D5', 'E5', 'G5']], [17, 3, 'A4', 'G5'], [18, 4, ['G4', 'B4'], 'G5'], [20, 0, ['F#4', 'A4'], '<REST>'], [20, 2, ['E4', 'G4'], 'E5'], [21, 2, ['G4', 'B4', 'D5'], 'E5'], [22, 2, ['F#4', 'A4', 'D5'], ['G4', 'B4']], [22, 3, ['F#4', 'A4', 'D5'], ['G4', 'B4']], [22, 4, 'D5', ['G4', 'B4']], [23, 0, 'B4', ['E4', 'G4']], [23, 3, ['G4', 'B4', 'D5'], 'E5'], [24, 1, 'D5', ['G4', 'B4']], [25, 0, ['D5', 'E5', 'G5'], ['E4', 'G4']], [25, 2, ['D5', 'E5', 'G5'], ['D5', 'G5', 'B5']], [26, 3, '<REST>', ['F#4', 'A4']], [26, 4, ['B4', 'D5', 'G5'], 'D5'], [28, 1, 'D5', 'E5'], [28, 2, 'D5', ['D5', 'E5', 'G5']], [28, 3, 'E5', 'B4'], [29, 3, ['D5', 'B5'], ['F#4', 'A4']], [30, 2, '<REST>', 'E5'], [30, 3, 'G5', ['G4', 'B4']], [30, 4, 'B5', '<REST>'], [32, 1, 'D5', ['E4', 'G4']], [32, 2, 'E5', 'A5'], [33, 2, 'D5', ['F#4', 'A4', 'D5']], [34, 0, 'E5', ['G4', 'B4']], [34, 1, ['D5', 'G5', 'B5'], ['F#4', 'A4']], [35, 0, ['B4', 'D5', 'G5'], ['D5', 'G5', 'B5']], [36, 1, ['D5', 'C6'], '<REST>'], [37, 0, ['D5', 'G5'], 'G5'], [38, 1, 'A5', ['D5', 'E5', 'G5']], [38, 2, 'A5', ['D5', 'B5']], [39, 0, 'G5', 'A4'], [39, 1, '<REST>', ['D4', 'G4', 'D5']], [40, 2, 'G5', 'E5'], [41, 1, '<REST>', 'D5'], [42, 1, 'E5', 'A4'], [43, 0, ['D5', 'G5'], ['D4', 'G4', 'D5']], [44, 0, ['D5', 'B5'], ['G4', 'B4']], [44, 5, 'G5', ['G4', 'B4']], [46, 1, 'D5', ['D5', 'B5']], [47, 2, 'D5', ['D5', 'G5']], [47, 3, 'E5', '<REST>'], [47, 4, ['D5', 'G5', 'B5'], ['D5', 'E5', 'G5']], [48, 1, ['B4', 'D5', 'G5'], '<REST>'], [49, 0, ['D5', 'C6'], '<REST>'], [49, 1, ['D5', 'B5'], ['D5', 'E5', 'G5']], [49, 2, ['D5', 'G5'], 'D5'], [50, 0, 'G5', 'E5'], [50, 2, 'A5', 'G4'], [50, 3, 'A5', ['G4', 'B4']], [51, 2, '<REST>', ['D5', 'G5']], [51, 3, ['D4', 'G4', 'D5'], '<REST>'], [51, 4, '<REST>', 'G4'], [52, 0, ['D4', 'G4', 'D5'], 'D5'], [52, 1, '<REST>', 'G4'], [52, 2, ['D4', 'G4', 'D5'], ['D5', 'C6']], [52, 3, '<REST>', 'G5'], [52, 4, ['D4', 'G4', 'D5'], ['D5', 'E5', 'G5']], [53, 0, '<REST>', 'E5'], [53, 1, ['D4', 'G4', 'D5'], ['D5', 'B5']], [53, 2, '<REST>', ['D5', 'G5']], [54, 0, '<REST>', 'A4'], [54, 1, '<REST>', ['D5', 'F#5', 'A5']], [54, 3, ['G4', 'B4'], ['F#4', 'A4']], [54, 4, ['G4', 'B4'], '<REST>'], [55, 0, ['G4', 'B4'], ['B4', 'D5', 'G5']], [55, 1, ['G4', 'B4'], ['D4', 'G4', 'D5']], [55, 2, 'A4', 'D5'], [55, 4, '<REST>', ['E4', 'G4']], [56, 0, ['G4', 'B4'], 'B5'], [56, 1, ['G4', 'B4'], ['D5', 'G5']], [57, 0, 'A4', 'A5'], [57, 1, ['G4', 'B4'], 'D5'], [57, 2, '<REST>', 'B4'], [58, 0, ['G4', 'B4'], 'B5'], [58, 1, ['G4', 'B4'], 'G5'], [58, 3, ['G4', 'B4'], '<REST>'], [58, 4, 'A4', 'G5'], [59, 0, ['F#4', 'A4'], ['D5', 'G5', 'B5']], [60, 0, ['E4', 'G4'], ['G4', 'B4']], [60, 1, 'D5', '<REST>'], [60, 2, 'B4', 'A5'], [60, 3, '<REST>', 'G5'], [60, 4, ['G4', 'B4'], ['D5', 'E5', 'G5']], [61, 0, ['G4', 'B4'], 'D5'], [61, 3, ['G4', 'B4'], ['D5', 'B5']], [61, 4, 'A4', '<REST>'], [62, 0, ['G4', 'B4'], ['D5', 'B5']], [62, 2, ['G4', 'B4'], 'G5'], [62, 3, ['G4', 'B4'], 'G5'], [62, 4, ['G4', 'B4'], 'A5'], [63, 0, ['G4', 'B4'], ['E4', 'G4']], [63, 1, 'A4', 'D5'], [63, 2, ['G4', 'B4'], 'G5'], [63, 3, '<REST>', 'E5'], [63, 4, ['G4', 'B4'], ['D4', 'G4', 'D5']], [64, 0, ['G4', 'B4'], '<REST>'], [64, 1, ['G4', 'B4'], 'A5'], [64, 3, ['G4', 'B4'], 'D5'], [64, 4, 'A4', ['D4', 'G4', 'D5']], [65, 0, ['F#4', 'A4'], 'A5'], [65, 1, '<REST>', 'D5'], [65, 3, ['F#4', 'A4'], '<REST>'], [65, 4, ['E4', 'G4'], '<REST>'], [66, 0, ['E4', 'G4'], ['D5', 'G5']], [66, 1, 'D5', 'A5'], [66, 2, 'B4', '<REST>'], [66, 3, '<REST>', ['D5', 'B5']], [66, 4, ['G4', 'B4', 'D5'], '<REST>'], [67, 0, 'D5', 'A4'], [67, 1, 'B4', 'A5'], [67, 2, 'A4', ['D5', 'C6']], [67, 3, 'G4', 'A5'], [67, 4, ['F#4', 'A4', 'D5'], 'A4'], [68, 0, ['F#4', 'A4', 'D5'], ['D5', 'B5']], [68, 1, 'D5', '<REST>'], [68, 2, 'B4', '<REST>'], [68, 3, 'A4', '<REST>'], [68, 4, 'G4', 'B5'], [69, 0, ['G4', 'B4', 'D5'], 'B5'], [69, 1, ['G4', 'B4', 'D5'], ['D4', 'G4', 'D5']], [69, 2, 'D5', 'A5'], [70, 0, 'B4', '<REST>'], [70, 1, 'A4', 'A5'], [70, 2, 'G4', '<REST>'], [70, 3, ['D5', 'E5', 'G5'], ['G4', 'B4']], [70, 4, ['D5', 'E5', 'G5'], ['D4', 'G4', 'D5']], [71, 0, ['D5', 'E5', 'G5'], 'G5'], [71, 1, ['D5', 'E5', 'G5'], ['D5', 'C6']], [71, 2, ['D5', 'E5', 'G5'], '<REST>'], [71, 3, ['D5', 'E5', 'G5'], ['G4', 'B4']], [71, 4, ['D5', 'F#5', 'A5'], 'D5'], [72, 0, ['D5', 'F#5', 'B5'], ['D5', 'G5']], [72, 1, '<REST>', 'D5'], [72, 2, ['B4', 'D5', 'G5'], 'A5'], [72, 3, 'D5', ['D5', 'G5']], [72, 4, 'E5', 'A4'], [73, 0, 'G5', ['G4', 'B4']], [73, 1, 'D5', 'G4'], [73, 2, '<REST>', 'D5'], [74, 0, 'D5', ['D5', 'E5', 'G5']], [74, 2, 'E5', ['D5', 'E5', 'G5']], [74, 3, ['D5', 'B5'], ['G4', 'B4']], [74, 4, ['D5', 'G5'], ['D4', 'G4', 'D5']], [75, 0, '<REST>', ['D4', 'G4', 'D5']], [75, 1, 'G5', 'A5'], [75, 2, ['D5', 'B5'], ['E4', 'G4']], [75, 3, ['D5', 'C6'], 'A5'], [75, 4, ['D5', 'B5'], ['D5', 'G5']], [76, 0, ['D5', 'G5'], ['D4', 'G4', 'D5']], [76, 1, '<REST>', 'G5'], [76, 2, 'G5', ['D5', 'G5']], [76, 3, 'B5', '<REST>'], [77, 0, 'A5', ['G4', 'B4']], [77, 1, 'A5', 'D5'], [77, 2, 'G5', ['G4', 'B4']], [77, 3, '<REST>', ['G4', 'B4']], [78, 0, ['B4', 'D5', 'G5'], '<REST>'], [78, 1, 'D5', ['D5', 'F#5', 'B5']], [78, 2, 'E5', ['F#4', 'A4']], [78, 3, 'G5', ['F#4', 'A4']], [78, 4, 'E5', 'D5'], [79, 0, '<REST>', 'G5'], [79, 1, 'D5', ['G4', 'B4']], [79, 2, 'E5', ['F#4', 'A4']], [79, 3, ['D5', 'G5', 'B5'], 'A4'], [79, 4, ['D5', 'G5', 'B5'], ['G4', 'B4']], [80, 0, ['B4', 'D5', 'G5'], 'A5'], [80, 1, '<REST>', ['G4', 'B4']], [80, 2, 'G5', ['G4', 'B4']], [80, 3, ['D5', 'B5'], 'B5'], [80, 4, ['D5', 'C6'], 'D5'], [81, 0, ['D5', 'B5'], '<REST>'], [81, 1, ['D5', 'G5'], 'G5'], [81, 2, '<REST>', 'D5'], [81, 3, 'G5', ['G4', 'B4', 'D5']], [82, 0, 'B5', ['D4', 'G4', 'D5']], [82, 1, 'A5', ['D5', 'B5']], [82, 2, 'A5', ['G4', 'B4']], [82, 3, 'G5', ['G4', 'B4']], [82, 4, '<REST>', 'G5'], [83, 0, ['B4', 'D5', 'G5'], ['G4', 'B4']], [83, 2, 'E5', ['G4', 'B4']], [83, 3, 'G5', '<REST>'], [83, 4, 'D5', '<REST>'], [84, 0, '<REST>', 'A5'], [84, 1, 'D5', 'G5'], [84, 2, 'D5', ['D5', 'B5']], [84, 3, 'E5', 'G5'], [84, 4, ['D5', 'B5'], ['D5', 'G5']], [85, 0, ['D5', 'G5'], ['E4', 'G4']], [85, 1, '<REST>', 'D5'], [85, 2, 'G5', 'A5'], [85, 3, ['D5', 'B5'], 'D5'], [85, 4, ['D5', 'C6'], '<REST>'], [86, 0, ['D5', 'B5'], ['D5', 'G5']], [86, 1, ['D5', 'G5'], 'B5'], [86, 2, '<REST>', 'A5'], [86, 3, 'G5', 'A4'], [86, 4, 'B5', 'G5'], [87, 0, 'A5', ['D5', 'B5']], [87, 1, 'A5', 'A4'], [87, 4, ['B4', 'D5', 'G5'], 'E5'], [88, 1, 'E5', ['F#4', 'A4']], [88, 2, 'G5', 'A5'], [88, 4, 'E5', '<REST>'], [89, 0, '<REST>', ['G4', 'B4']], [89, 2, 'E5', ['G4', 'B4']], [89, 3, ['D5', 'G5', 'B5'], 'G5'], [89, 4, ['D5', 'G5', 'B5'], ['D5', 'E5', 'G5']], [90, 0, ['B4', 'D5', 'G5'], 'G5'], [90, 1, '<REST>', ['F#4', 'A4']], [90, 2, 'G5', 'D5'], [90, 3, ['D5', 'B5'], ['B4', 'D5', 'G5']], [90, 4, ['D5', 'C6'], 'A5'], [91, 0, ['D5', 'B5'], '<REST>'], [91, 1, ['D5', 'G5'], 'A4'], [91, 2, '<REST>', 'G5'], [91, 3, 'G5', ['D5', 'F#5', 'A5']], [91, 4, 'B5', 'A4'], [92, 0, 'A5', '<REST>'], [92, 1, 'A5', 'D5'], [92, 2, 'G5', ['G4', 'B4']], [92, 3, '<REST>', ['G4', 'B4']], [92, 4, 'D5', '<REST>'], [93, 0, 'B5', ['B4', 'D5', 'G5']], [93, 1, 'A5', ['D5', 'B5']], [93, 2, 'A5', ['D4', 'G4', 'D5']], [93, 3, 'G5', 'A5'], [93, 4, 'G5', '<REST>'], [93, 5, 'E5', ['F#4', 'A4']], [94, 0, 'D5', ['D5', 'G5', 'B5']], [95, 0, 'D5', ['B4', 'D5', 'G5']], [95, 1, 'D5', 'G5']]
report_list1 = clean_report_list(test1)    
report_list2 = clean_report_list(test2)  
print(report_list1)
print(report_list2)

latex_file = 'New_Variation_Report.tex'

with open(latex_file, 'w') as f:
    f.write(r'\documentclass{article}' + '\n')
    f.write(r'\usepackage{longtable}' + '\n')
    f.write(r'\usepackage[a4paper,margin=0.5in]{geometry}' + '\n')
    f.write(r'\begin{document}' + '\n')
    
    f.write(r'\section*{About New Variation Report}' + '\n')
    f.write(r'This PDF is designed to show the location of the original notes and the notes that have been changed in the MIDI file.' + '\n')
    
    f.write(r'\section*{Melody Part Result}')
    f.write(r'\begin{longtable}{|c|c|c|c|}' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'Room & Note Location & Original Note & New Variation Note \\ \hline' + '\n')
    f.write(r'\endfirsthead' + '\n')
    f.write(r'\multicolumn{4}{c}{{\tablename\ \thetable{} Melody Part Result}} \\' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'Room & Location & Original Note & New Variation Note \\ \hline' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'\endhead' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'\multicolumn{4}{r}{Next page}')
    f.write(r'\endfoot' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'\endlastfoot' + '\n')
    
    room_check1 = 1
    for row in report_list1:
        room = row[0]
        location = row[1]
        original_note = row[2]
        new_variation_note = row[3]
        
        if isinstance(original_note, list):
            original_note = ', '.join(original_note)

        if isinstance(new_variation_note, list):
            new_variation_note = ', '.join(new_variation_note)
            
        if room != room_check1:
            f.write(r'\hline' + '\n')
            room_check1 += 1
        f.write(f'{room} & {location} & {original_note} & {new_variation_note} \\\ ' + '\n')

    f.write(r'\hline' + '\n')
    f.write(r'\end{longtable}' + '\n')
    
    f.write(r'\section*{Bass Part Result}')
    f.write(r'\begin{longtable}{|c|c|c|c|}' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'Room & Note Location & Original Note & New Variation Note \\ \hline' + '\n')
    f.write(r'\endfirsthead' + '\n')
    f.write(r'\multicolumn{4}{c}{{\tablename\ \thetable{} Bass Part Result}} \\' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'Room & Location & Original Note & New Variation Note \\ \hline' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'\endhead' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'\multicolumn{4}{r}{next page}')
    f.write(r'\endfoot' + '\n')
    f.write(r'\hline' + '\n')
    f.write(r'\endlastfoot' + '\n')
    
    room_check2 = 1
    for row in report_list2:
        room = row[0]
        location = row[1]
        original_note = row[2]
        new_variation_note = row[3]
        
        if isinstance(original_note, list):
            original_note = ', '.join(original_note)

        if isinstance(new_variation_note, list):
            new_variation_note = ', '.join(new_variation_note)
            
        if room != room_check2:
            f.write(r'\hline' + '\n')
            room_check2 += 1
        f.write(f'{room} & {location} & {original_note} & {new_variation_note} \\\ ' + '\n')

    f.write(r'\hline' + '\n')
    f.write(r'\end{longtable}' + '\n')
    f.write(r'\end{document}' + '\n')

process = subprocess.Popen(['pdflatex', latex_file], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

stdout, stderr = process.communicate()

print("pdflatex output:")
print(stdout.decode())
print("\npdflatex Result:")
print(stderr.decode())

if process.returncode == 0:
    print("pdflatex compilation successful.")
else:
    print(f"pdflatex compilation failed with return code {process.returncode}.")
# Out:
# [[1, 3, 'REST', 'D5'], [1, 4, ['D4', 'G4', 'D5'], 'D5'], [1, 7, 'REST', ['D5', 'B5']], [2, 1, 'REST', 'G5'], [2, 2, ['D4', 'G4', 'D5'], 'G5'], [2, 3, 'REST', ['D4', 'G4', 'D5']], [2, 4, ['D4', 'G4', 'D5'], 'A5'], [2, 5, 'REST', ['D5', 'G5']], [2, 6, ['D4', 'G4', 'D5'], 'REST'], [3, 2, ['G4', 'B4'], ['B4', 'D5', 'G5']], [4, 3, ['G4', 'B4'], ['E4', 'G4', 'B4']], [4, 5, ['G4', 'B4'], 'A4'], [4, 8, ['G4', 'B4'], ['D5', 'B5']], [5, 3, ['G4', 'B4'], 'D5'], [5, 4, ['G4', 'B4'], ['D4', 'G4', 'D5']], [5, 6, ['G4', 'B4'], ['D5', 'B5']], [6, 2, ['F\\#4', 'A4'], 'REST'], [6, 3, ['F\\#4', 'A4'], 'G5'], [6, 4, ['E4', 'G4'], ['D5', 'E5', 'G5']], [6, 5, ['E4', 'G4'], 'B4'], [7, 1, 'REST', 'G5'], [7, 3, ['G4', 'B4'], 'A5'], [8, 2, ['G4', 'B4'], 'D5'], [8, 3, ['G4', 'B4'], ['D5', 'B5']], [8, 6, ['G4', 'B4'], ['D5', 'E5', 'G5']], [8, 7, 'A4', 'G5'], [9, 5, ['G4', 'B4'], 'G5'], [10, 2, ['F\\#4', 'A4'], 'REST'], [10, 4, ['E4', 'G4'], 'E5'], [11, 2, ['G4', 'B4', 'D5'], 'E5'], [12, 1, ['F\\#4', 'A4', 'D5']
# ...
